# %%
# 1️⃣ Importing libraries
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# 2️⃣ Downloading data
data = yf.download("AAPL", start="2022-01-01", end="2023-01-01")
print(data.head())
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_12660\1349336308.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2022-01-01", end="2023-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-01-03  178.645660  179.499589  174.425155  174.542932  104487900
# 2022-01-04  176.378372  179.558489  175.809091  179.254221   99310400
# 2022-01-05  171.686676  176.839632  171.411853  176.289986   94537600
# 2022-01-06  168.820663  172.059668  168.467317  169.507721   96904000
# 2022-01-07  168.987564  170.921151  167.868637  169.694257   86709100

# %%
# 3️⃣ Plotting closing price
plt.figure(figsize=(10,5))
plt.plot(data['Close'], label='AAPL Close Price')
plt.title("Apple Stock Price (2022)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
